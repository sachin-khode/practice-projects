# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sonar_df = pd.read_csv("/home/sachin/Downloads/sonar.all-data.csv") #reading data
sonar_df
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
sonar_df.shape
# Out:
# (207, 61)

# %%
sonar_df.columns
# Out:
# Index(['0.0200', '0.0371', '0.0428', '0.0207', '0.0954', '0.0986', '0.1539',
#        '0.1601', '0.3109', '0.2111', '0.1609', '0.1582', '0.2238', '0.0645',
#        '0.0660', '0.2273', '0.3100', '0.2999', '0.5078', '0.4797', '0.5783',
#        '0.5071', '0.4328', '0.5550', '0.6711', '0.6415', '0.7104', '0.8080',
#        '0.6791', '0.3857', '0.1307', '0.2604', '0.5121', '0.7547', '0.8537',
#        '0.8507', '0.6692', '0.6097', '0.4943', '0.2744', '0.0510', '0.2834',
#        '0.2825', '0.4256', '0.2641', '0.1386', '0.1051', '0.1343', '0.0383',
#        '0.0324', '0.0232', '0.0027', '0.0065', '0.0159', '0.0072', '0.0167',
#        '0.0180', '0.0084', '0.0090', '0.0032', 'R'],
#       dtype='object')

# %%
sonar_df.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#    0.0090  0.0032  R
# 0  0.0052  0.0044  R
# 1  0.0095  0.0078  R
# 2  0.0040  0.0117  R
# ...

# %%
sonar_df.tail()
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
#      0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 202  0.2684  ...  0.0116  0.0098  0.0199  0.0033  0.0101  0.0065  0.0115
# 203  0.2154  ...  0.0061  0.0093  0.0135  0.0063  0.0063  0.0034  0.0032
# 204  0.2529  ...  0.0160  0.0029  0.0051  0.0062  0.0089  0.0140  0.0138
# 205  0.2354  ...  0.0086  0.0046  0.0126  0.0036  0.0035  0.0034  0.0079
# 206  0.2354  ...  0.0146  0.0129  0.0047  0.0039  0.0061  0.0040  0.0036
#
#      0.0090  0.0032  R
# 202  0.0193  0.0157  M
# ...

# %%
sonar_df.describe()
# Out:
#            0.0200      0.0371      0.0428      0.0207      0.0954      0.0986  \
# count  207.000000  207.000000  207.000000  207.000000  207.000000  207.000000
# mean     0.029208    0.038443    0.043837    0.054053    0.075105    0.104599
# std      0.023038    0.033040    0.038521    0.046583    0.055669    0.059247
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013300    0.016400    0.018900    0.024450    0.037700    0.066950
# 50%      0.022800    0.030800    0.034200    0.044100    0.062000    0.092100
# 75%      0.035800    0.048100    0.058200    0.065700    0.101050    0.134150
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#            0.1539      0.1601      0.3109      0.2111  ...      0.0232  \
# count  207.000000  207.000000  207.000000  207.000000  ...  207.000000
# mean     0.121591    0.134677    0.177361    0.208245  ...    0.016034
# ...

# %%
column_name = []
for i in range(1,62):
    col = "column"
    col1 = col+str(i)
    column_name.append(col1)

# %%
print(column_name)
# Out:
# ['column1', 'column2', 'column3', 'column4', 'column5', 'column6', 'column7', 'column8', 'column9', 'column10', 'column11', 'column12', 'column13', 'column14', 'column15', 'column16', 'column17', 'column18', 'column19', 'column20', 'column21', 'column22', 'column23', 'column24', 'column25', 'column26', 'column27', 'column28', 'column29', 'column30', 'column31', 'column32', 'column33', 'column34', 'column35', 'column36', 'column37', 'column38', 'column39', 'column40', 'column41', 'column42', 'column43', 'column44', 'column45', 'column46', 'column47', 'column48', 'column49', 'column50', 'column51', 'column52', 'column53', 'column54', 'column55', 'column56', 'column57', 'column58', 'column59', 'column60', 'column61']

# %%
sonar_df.columns = column_name

# %%
sonar_df.columns
# Out:
# Index(['column1', 'column2', 'column3', 'column4', 'column5', 'column6',
#        'column7', 'column8', 'column9', 'column10', 'column11', 'column12',
#        'column13', 'column14', 'column15', 'column16', 'column17', 'column18',
#        'column19', 'column20', 'column21', 'column22', 'column23', 'column24',
#        'column25', 'column26', 'column27', 'column28', 'column29', 'column30',
#        'column31', 'column32', 'column33', 'column34', 'column35', 'column36',
#        'column37', 'column38', 'column39', 'column40', 'column41', 'column42',
#        'column43', 'column44', 'column45', 'column46', 'column47', 'column48',
#        'column49', 'column50', 'column51', 'column52', 'column53', 'column54',
#        'column55', 'column56', 'column57', 'column58', 'column59', 'column60',
#        'column61'],
#       dtype='object')

# %%
sonar_df.describe()
sonar_df.head()
# Out:
#    column1  column2  column3  column4  column5  column6  column7  column8  \
# 0   0.0453   0.0523   0.0843   0.0689   0.1183   0.2583   0.2156   0.3481
# 1   0.0262   0.0582   0.1099   0.1083   0.0974   0.2280   0.2431   0.3771
# 2   0.0100   0.0171   0.0623   0.0205   0.0205   0.0368   0.1098   0.1276
# 3   0.0762   0.0666   0.0481   0.0394   0.0590   0.0649   0.1209   0.2467
# 4   0.0286   0.0453   0.0277   0.0174   0.0384   0.0990   0.1201   0.1833
#
#    column9  column10  ...  column52  column53  column54  column55  column56  \
# 0   0.3337    0.2872  ...    0.0084    0.0089    0.0048    0.0094    0.0191
# 1   0.5598    0.6194  ...    0.0232    0.0166    0.0095    0.0180    0.0244
# 2   0.0598    0.1264  ...    0.0121    0.0036    0.0150    0.0085    0.0073
# 3   0.3564    0.4459  ...    0.0031    0.0054    0.0105    0.0110    0.0015
# 4   0.2105    0.3039  ...    0.0045    0.0014    0.0038    0.0013    0.0089
#
#    column57  column58  column59  column60  column61
# ...

# %%
print(sonar_df.dtypes)
# Out:
# column1     float64
# column2     float64
# column3     float64
# column4     float64
# column5     float64
#              ...
# column57    float64
# column58    float64
# column59    float64
# column60    float64
# column61     object
# Length: 61, dtype: object

# %%
print(sonar_df.isnull().sum())
# Out:
# column1     0
# column2     0
# column3     0
# column4     0
# column5     0
#            ..
# column57    0
# column58    0
# column59    0
# column60    0
# column61    0
# Length: 61, dtype: int64

# %%
plt.scatter(sonar_df.iloc[:,1],sonar_df.iloc[:,2])
plt.show()

# %%
sns.heatmap(sonar_df.isnull())

# %%
sonar_df.plot.box(figsize=(12,8))

# %%
sns.set(style="darkgrid")
sns.countplot(x="column61",data=sonar_df)

# %%
sonar_df['column61'].value_counts()
# Out:
# M    111
# R     96
# Name: column61, dtype: int64

# %%
y = sonar_df.iloc[:,-1]
print(y)
# Out:
# 0      R
# 1      R
# 2      R
# 3      R
# 4      R
#       ..
# 202    M
# 203    M
# 204    M
# 205    M
# 206    M
# Name: column61, Length: 207, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder   
le=LabelEncoder()
c61 =le.fit_transform(c61)
print(c61)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-148-331b5cfb4cf8> in <module>
#       1 from sklearn.preprocessing import LabelEncoder
#       2 le=LabelEncoder()
# ----> 3 c61 =le.fit_transform(c61)
#       4 print(c61)
#
# NameError: name 'c61' is not defined

# %%
x=sonar_df.iloc[:,0:-1]
print(x)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y)

# print("x train----->",x_train)
# print("y train--->",y_train)
# print("x test----->",x_test)
# print("y test---->",y_test)

clf = LogisticRegression()
clf.fit(x_train,y_train)

# %%
pred=clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print("accuracy_score :",accuracy_score(pred,y_test))

# %%
import matplotlib.pyplot as plt 
sonar_df.hist()

# %%
x_test.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-149-189e6887f2da> in <module>
# ----> 1 x_test.shape
#
# NameError: name 'x_test' is not defined
